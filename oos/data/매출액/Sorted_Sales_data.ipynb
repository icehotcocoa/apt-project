# %%
import pandas as pd

# %%
# 데이터 불러오기
dong = pd.read_csv(r'D:\Work\project\project2\oos\data\거주인구\Resident_Population_Dong424.csv')

d19 = pd.read_csv('sales_2019.csv')
d20 = pd.read_csv('sales_2020.csv')
d21 = pd.read_csv('sales_2021.csv')
d22 = pd.read_csv('sales_2022.csv')
d2324 = pd.read_csv('sales_2023,2024.csv')

# %%
d19.info()
print('년분기 갯수 : ', d19['기준_년분기_코드'].nunique())
print('업종명 갯수 : ', d19['서비스_업종_코드_명'].nunique())
print('행정동 갯수 : ', d19['행정동_코드_명'].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65758 entries, 0 to 65757
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준_년분기_코드        65758 non-null  int64
#  1   행정동_코드           65758 non-null  int64
#  2   행정동_코드_명         65758 non-null  object
#  3   서비스_업종_코드        65758 non-null  object
#  4   서비스_업종_코드_명      65758 non-null  object
#  5   당월_매출_금액         65758 non-null  int64
#  6   당월_매출_건수         65758 non-null  int64
#  7   주중_매출_금액         65758 non-null  int64
#  8   주말_매출_금액         65758 non-null  int64
#  9   월요일_매출_금액        65758 non-null  int64
#  10  화요일_매출_금액        65758 non-null  int64
#  11  수요일_매출_금액        65758 non-null  int64
#  12  목요일_매출_금액        65758 non-null  int64
#  13  금요일_매출_금액        65758 non-null  int64
#  14  토요일_매출_금액        65758 non-null  int64
#  15  일요일_매출_금액        65758 non-null  int64
#  16  시간대_00~06_매출_금액  65758 non-null  int64
# ...

# %%
d20.info()
print('년분기 갯수 : ', d20['기준_년분기_코드'].nunique())
print('업종명 갯수 : ', d20['서비스_업종_코드_명'].nunique())
print('행정동 갯수 : ', d20['행정동_코드_명'].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66583 entries, 0 to 66582
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준_년분기_코드        66583 non-null  int64
#  1   행정동_코드           66583 non-null  int64
#  2   행정동_코드_명         66583 non-null  object
#  3   서비스_업종_코드        66583 non-null  object
#  4   서비스_업종_코드_명      66583 non-null  object
#  5   당월_매출_금액         66583 non-null  int64
#  6   당월_매출_건수         66583 non-null  int64
#  7   주중_매출_금액         66583 non-null  int64
#  8   주말_매출_금액         66583 non-null  int64
#  9   월요일_매출_금액        66583 non-null  int64
#  10  화요일_매출_금액        66583 non-null  int64
#  11  수요일_매출_금액        66583 non-null  int64
#  12  목요일_매출_금액        66583 non-null  int64
#  13  금요일_매출_금액        66583 non-null  int64
#  14  토요일_매출_금액        66583 non-null  int64
#  15  일요일_매출_금액        66583 non-null  int64
#  16  시간대_00~06_매출_금액  66583 non-null  int64
# ...

# %%
set_a = set(d19['행정동_코드_명'])
set_b = set(dong['동별'])
common_values = set_a & set_b  # A와 B에 모두 있는 값
only_in_a = set_a - set_b  # A에만 있는 값
only_in_b = set_b - set_a  # B에만 있는 값

# 결과 출력
print("A와 B에 모두 있는 값:")
print(common_values)

print("\nA에만 있는 값:")
print(only_in_a)

print("\nB에만 있는 값:")
print(only_in_b)
# Out:
# A와 B에 모두 있는 값:
# ...

# %%
dong[dong['동별'].str.contains('^둔촌', na=False)]
# Out:
#       동별  20191  20192  20193  20194  20201  20202  20203  20204  20211  ...  \
# 91  둔촌1동    298    289    287    283    279    274    272    262    146  ...
# 92  둔촌2동  28056  27964  27943  27752  27520  27292  27085  26413  25309  ...
#
#     20221  20222  20223  20224  20231  20232  20233  20234  20241  20242
# 91    143    143     81     73     74     70     71     61     61     60
# 92  24641  24480  24343  24277  24212  24169  24387  24417  24354  24231
#
# [2 rows x 23 columns]

# %%
d19.head(2)
# Out:
#    기준_년분기_코드    행정동_코드 행정동_코드_명 서비스_업종_코드 서비스_업종_코드_명   당월_매출_금액  당월_매출_건수  \
# 0      20191  11380510      녹번동  CS200016         당구장   37837940      2544
# 1      20191  11380510      녹번동  CS200007        치과의원  238363333      2682
#
#     주중_매출_금액  주말_매출_금액  월요일_매출_금액  ...  시간대_건수~21_매출_건수  시간대_건수~24_매출_건수  \
# 0   24879147  12958793    5376153  ...             1018              955
# 1  173213042  65150291   50931757  ...              403                0
#
#    남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
# 0      2312       232           162           275           221          1137
# 1      1425      1257             0           145           330           641
#
#    연령대_50_매출_건수  연령대_60_이상_매출_건수
# 0           711               38
# 1           775              791
#
# [2 rows x 53 columns]

# %%
d19.columns
# Out:
# Index(['기준_년분기_코드', '행정동_코드', '행정동_코드_명', '서비스_업종_코드', '서비스_업종_코드_명',
#        '당월_매출_금액', '당월_매출_건수', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
#        '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
#        '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
#        '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
#        '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
#        '연령대_50_매출_건수', '연령대_60_이상_매출_건수'],
#       dtype='object')

# %%
col = ['기준_년분기_코드', '행정동_코드', '행정동_코드_명', '서비스_업종_코드_명',
       '당월_매출_금액', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
       '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
       '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
       '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
       '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
       '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액']

d19 = d19[col]
d20 = d20[col]
d21 = d21[col]
d22 = d22[col]
d2324 = d2324[col]

# %%
d19.columns
# Out:
# Index(['기준_년분기_코드', '행정동_코드', '행정동_코드_명', '서비스_업종_코드_명', '당월_매출_금액',
#        '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액', '수요일_매출_금액',
#        '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액', '시간대_00~06_매출_금액',
#        '시간대_06~11_매출_금액', '시간대_11~14_매출_금액', '시간대_14~17_매출_금액',
#        '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액',
#        '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
#        '연령대_50_매출_금액', '연령대_60_이상_매출_금액'],
#       dtype='object')

# %%
col_name = ['년분기', '행정동_코드', '행정동', '업종명', '월매출',
       '주중매출', '주말매출', '월요일', '화요일', '수요일','목요일', '금요일', '토요일', '일요일',
       '0006','0611', '1114', '1417', '1721', '2124',
       '남성', '여성',
       'Age_10', 'Age_20', 'Age_30', 'Age_40','Age_50', 'Age_60_to_end']

d19.columns = col_name
d20.columns = col_name
d21.columns = col_name
d22.columns = col_name
d2324.columns = col_name

# %%
d19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65758 entries, 0 to 65757
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   년분기            65758 non-null  int64
#  1   행정동_코드         65758 non-null  int64
#  2   행정동            65758 non-null  object
#  3   업종명            65758 non-null  object
#  4   월매출            65758 non-null  int64
#  5   주중매출           65758 non-null  int64
#  6   주말매출           65758 non-null  int64
#  7   월요일            65758 non-null  int64
#  8   화요일            65758 non-null  int64
#  9   수요일            65758 non-null  int64
#  10  목요일            65758 non-null  int64
#  11  금요일            65758 non-null  int64
#  12  토요일            65758 non-null  int64
#  13  일요일            65758 non-null  int64
#  14  0006           65758 non-null  int64
#  15  0611           65758 non-null  int64
#  16  1114           65758 non-null  int64
#  17  1417           65758 non-null  int64
# ...

# %%
# DataFrame 합치기
combined_df = pd.concat([d19, d20, d21, d22, d2324], ignore_index=True)

# 오름차순 정렬 (예: 특정 컬럼 'Date' 기준으로)
sorted_df = combined_df.sort_values(by='년분기', ascending=True)

# 결과 저장 (선택사항)
#sorted_df.to_csv('Sorted_Salaes_of_Stores.csv', index=False)

# 결과 확인
#print(sorted_df.head())
# Out:
#      년분기    행정동_코드   행정동    업종명        월매출       주중매출       주말매출       월요일  \
# 8  20191  11380570   대조동    네일숍   46878551   26348890   20529661   3632220
# 7  20191  11380570   대조동     서적   78382744   78382744          0  32342731
# 6  20191  11380520  불광1동   의료기기  277934737  274578708    3356029    671206
# 5  20191  11380570   대조동  골프연습장   54746431   31575096   23171335   6634905
# 4  20191  11380570   대조동  커피-음료  779058661  507363643  271695018  85425895
#
#          화요일        수요일  ...       1721       2124         남성         여성  \
# 8    2050855    8508002  ...   19877033     926375    2740146   44138405
# 7          0          0  ...    6618977          0   71693576    5716390
# 6   92402960    1168289  ...    4027235          0    7880347  270054390
# 5    6174052    6052062  ...   13615447   16190792   36468253   11507730
# 4  100997214  105099351  ...  187016840  105794708  334216816  444841845
#
#      Age_10     Age_20     Age_30     Age_40     Age_50  Age_60_to_end
# ...

# %%
sorted_df.info()
print('년분기 갯수 : ', sorted_df['년분기'].nunique())
print('업종명 갯수 : ', sorted_df['업종명'].nunique())
print('행정동 갯수 : ', sorted_df['행정동'].nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 368339 entries, 8 to 368294
# Data columns (total 28 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   년분기            368339 non-null  int64
#  1   행정동_코드         368339 non-null  int64
#  2   행정동            368339 non-null  object
#  3   업종명            368339 non-null  object
#  4   월매출            368339 non-null  int64
#  5   주중매출           368339 non-null  int64
#  6   주말매출           368339 non-null  int64
#  7   월요일            368339 non-null  int64
#  8   화요일            368339 non-null  int64
#  9   수요일            368339 non-null  int64
#  10  목요일            368339 non-null  int64
#  11  금요일            368339 non-null  int64
#  12  토요일            368339 non-null  int64
#  13  일요일            368339 non-null  int64
#  14  0006           368339 non-null  int64
#  15  0611           368339 non-null  int64
#  16  1114           368339 non-null  int64
# ...
