# %%
import pandas as pd

# %%
data = pd.read_csv('서울시 거주인구 (동,분기).csv')

# %%
data[50:60]
# Out:
#      동별       구분별          항목   단위  2019. 1/4  2019. 2/4  2019. 3/4  \
# 50  부암동        남자  주민등록인구(동별)  NaN    5012.00    4989.00    5002.00
# 51  부암동        여자  주민등록인구(동별)  NaN    5511.00    5488.00    5523.00
# 52  부암동       한국인  주민등록인구(동별)    명   10111.00   10068.00   10017.00
# 53  부암동        남자  주민등록인구(동별)  NaN    4832.00    4801.00    4765.00
# 54  부암동        여자  주민등록인구(동별)  NaN    5279.00    5267.00    5252.00
# 55  부암동     등록외국인  주민등록인구(동별)    명     412.00     409.00     508.00
# 56  부암동        남자  주민등록인구(동별)  NaN     180.00     188.00     237.00
# 57  부암동        여자  주민등록인구(동별)  NaN     232.00     221.00     271.00
# 58  부암동     세대당인구  주민등록인구(동별)    명       2.35       2.35       2.35
# 59  부암동  65세이상고령자  주민등록인구(동별)    명    1752.00    1747.00    1754.00
#
#     2019. 4/4  2020. 1/4    2020. 2/4  ...  2022. 2/4  2022. 3/4  2022. 4/4  \
# 50    5045.00    5042.00   4953.00000  ...    4630.00    4578.00    4545.00
# ...
