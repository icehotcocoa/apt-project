# %%
import pandas as pd

# %%
data_01 = pd.read_csv('서울시_상권분석서비스(점포-행정동)_2022년.csv', encoding='EUC-KR')
data_02 = pd.read_csv(r'D:\Work\team_project\project2\oos\data\거주인구\Resident_Population_Dong424.csv')

# %%
data_01.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141334 entries, 0 to 141333
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   기준_년분기_코드    141334 non-null  int64
#  1   행정동_코드       141334 non-null  int64
#  2   행정동_코드_명     141334 non-null  object
#  3   서비스_업종_코드    141334 non-null  object
#  4   서비스_업종_코드_명  141334 non-null  object
#  5   점포_수         141334 non-null  int64
#  6   유사_업종_점포_수   141334 non-null  int64
#  7   개업_율         141334 non-null  int64
#  8   개업_점포_수      141334 non-null  int64
#  9   폐업_률         141334 non-null  int64
#  10  폐업_점포_수      141334 non-null  int64
#  11  프랜차이즈_점포_수   141334 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 12.9+ MB

# %%
set_a = set(data_01['행정동_코드_명'])
set_b = set(data_02['동별'])
common_values = set_a & set_b  # A와 B에 모두 있는 값
only_in_a = set_a - set_b  # A에만 있는 값
only_in_b = set_b - set_a  # B에만 있는 값

# %%
# 결과 출력
print("A와 B에 모두 있는 값:")
print(common_values)

print("\nA에만 있는 값:")
print(only_in_a)

print("\nB에만 있는 값:")
print(only_in_b)
# Out:
# A와 B에 모두 있는 값:
# {'청운효자동', '수유2동', '신원동', '이문1동', '길동', '서교동', '거여2동', '정릉4동', '쌍문3동', '중곡3동', '우이동', '중계2·3동', '불광1동', '면목5동', '거여1동', '잠실3동', '암사3동', '시흥2동', '공덕동', '마천2동', '성산2동', '일원본동', '응암1동', '북가좌2동', '면목본동', '중곡1동', '둔촌2동', '창신3동', '신길4동', '대학동', '공릉2동', '갈현2동', '번3동', '신사2동', '신길3동', '용신동', '장안1동', '월계1동', '신월2동', '중화1동', '반포4동', '여의동', '면목7동', '삼성1동', '상계8동', '보문동', '신월4동', '삼전동', '잠원동', '면목4동', '행당2동', '개봉3동', '목5동', '중계본동', '숭인1동', '증산동', '장위1동', '문정2동', '구의2동', '신길5동', '풍납1동', '난곡동', '길음1동', '약수동', '홍제1동', '도곡1동', '진관동', '이문2동', '정릉3동', '신정6동', '방학1동', '쌍문4동', '옥수동', '창신1동', '면목3·8동', '일원1동', '종암동', '서원동', '시흥1동', '암사2동', '수서동', '잠실6동', '이촌1동', '목1동', '자양4동', '송정동', '등촌3동', '응봉동', '신정2동', '공항동', '신촌동', '위례동', '다산동', '보라매동', '신정7동', '강일동', '연남동', '반포3동', '자양3동', '갈현1동', '반포본동', '성수2가3동', '상계10동', '합정동', '답십리1동', '남현동', '필동', '금호2·3가동', '신림동', '마천1동', '신월5동', '양평1동', '창5동', '대흥동', '사근동', '구로3동', '이태원1동', '교남동', '노량진2동', '용답동', '삼성동', '대치4동', '혜화동', '상계5동', '용문동', '사직동', '이태원2동', '서초4동', '신내1동', '목2동', '방배본동', '효창동', '도곡2동', '명일2동', '오류2동', '화곡1동', '당산1동', '염창동', '성수1가1동', '월계2동', '천연동', '반포2동', '망원2동', '신월7동', '상도2동', '종로5·6가동', '청량리동', '수유1동', '창3동', '상도4동', '홍제2동', '천호3동', '시흥3동', '방화3동', '화양동', '중곡4동', '청담동', '신당5동', '금호4가동', '독산3동', '상계1동', '고덕1동', '낙성대동', '독산2동', '삼양동', '방배4동', '홍은1동', '가양3동', '제기동', '영등포동', '오류1동', '대림2동', '고척1동', '종로1·2·3·4가동', '방배2동', '역삼2동', '구로1동', '인수동', '등촌1동', '수궁동', '중계1동', '은천동', '상일동', '대림3동', '묵2동', '신정1동', '남가좌2동', '우장산동', '무악동', '묵1동', '서초3동', '남가좌1동', '상봉1동', '평창동', '대조동', '망우본동', '신길6동', '성내2동', '북가좌1동', '신정4동', '개포4동', '황학동', '신대방2동', '중앙동', '남영동', '잠실7동', '잠실2동', '방화2동', '인헌동', '번2동', '응암3동', '면목2동', '상봉2동', '창2동', '돈암2동', '성내3동', '정릉2동', '이촌2동', '도림동', '원효로1동', '자양2동', '석촌동', '성북동', '장안2동', '세곡동', '중곡2동', '양재1동', '신길7동', '고덕2동', '개포2동', '장위3동', '중계4동', '발산1동', '오금동', '신당동', '신사1동', '하계1동', '미아동', '신사동', '답십리2동', '천호1동', '하계2동', '도화동', '화곡3동', '서강동', '행운동', '목4동', '상도3동', '도봉1동', '암사1동', '조원동', '영등포본동', '시흥4동', '신정3동', '역삼1동', '광장동', '회기동', '양재2동', '안암동', '금호1가동', '사당5동', '난향동', '일원2동', '가락2동', '중림동', '월곡2동', '석관동', '등촌2동', '방배1동', '대치1동', '회현동', '자양1동', '상계6·7동', '청룡동', '사당4동', '사당2동', '행당1동', '반포1동', '왕십리2동', '노량진1동', '녹번동', '아현동', '서초2동', '신수동', '송파1동', '화곡2동', '가리봉동', '개포1동', '성내1동', '홍제3동', '삼청동', '목3동', '삼각산동', '구의1동', '상계9동', '쌍문2동', '서빙고동', '장위2동', '한남동', '잠실본동', '이화동', '불광2동', '양평2동', '구로4동', '성산1동', '신월1동', '성현동', '후암동', '사당1동', '신길1동', '천호2동', '전농2동', '광희동', '신내2동', '방화1동', '대림1동', '장충동', '원효로2동', '상계3·4동', '월곡1동', '논현2동', '홍은2동', '청림동', '방이2동', '고척2동', '수유3동', '화곡6동', '방이1동', '공릉1동', '방학3동', '대치2동', '송파2동', '흑석동', '중화2동', '을지로동', '휘경2동', '풍납2동', '신대방1동', '독산1동', '가양2동', '장지동', '전농1동', '오륜동', '번1동', '보광동', '역촌동', '사당3동', '상도1동', '문래동', '휘경1동', '구의3동', '용강동', '성수2가1동', '월계3동', '방배3동', '성수1가2동', '신월6동', '동화동', '길음2동', '서초1동', '충현동', '정릉1동', '논현1동', '명일1동', '연희동', '미성동', '왕십리도선동', '돈암1동', '창1동', '마장동', '군자동', '수색동', '응암2동', '개봉2동', '화곡본동', '서림동', '송중동', '창신2동', '가산동', '시흥5동', '신도림동', '화곡8동', '청파동', '북아현동', '독산4동', '숭인2동', '가락본동', '삼성2동', '부암동', '용산2가동', '동선동', '상계2동', '가회동', '대방동', '당산2동', '둔촌1동', '신월3동', '문정1동', '상암동', '압구정동', '망원1동', '능동', '삼선동', '가락1동', '구산동', '도봉2동', '잠실4동', '내곡동', '망우3동', '한강로동', '가양1동', '송천동', '쌍문1동', '소공동', '구로2동', '명동', '창4동', '청구동', '방학2동', '개봉1동', '구로5동', '화곡4동', '염리동'}
#
# A에만 있는 값:
# {'항동'}
#
# B에만 있는 값:
# {'관악구 신사동'}

# %%
data_01.loc[data_01['행정동_코드'] == 11620685, '행정동_코드_명'] = '관악구 신사동'

# %%
data_01[data_01['행정동_코드_명'] == '관악구 신사동'][:1]
# Out:
#        기준_년분기_코드    행정동_코드 행정동_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  유사_업종_점포_수  \
# 27505      20221  11620685  관악구 신사동  CS100001       한식음식점   119         130
#
#        개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 27505     4        5     3        4          11

# %%
dong_check = data_01[data_01['행정동_코드_명'] == '신사동']

# %%
dong_check.head(1)
# Out:
#        기준_년분기_코드    행정동_코드 행정동_코드_명 서비스_업종_코드 서비스_업종_코드_명  점포_수  유사_업종_점포_수  \
# 29749      20221  11680510      신사동  CS100001       한식음식점   286         320
#
#        개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 29749     3        9     3        8          34

# %%
set_a = set(data_01['행정동_코드_명'])
set_b = set(data_02['동별'])
common_values = set_a & set_b  # A와 B에 모두 있는 값
only_in_a = set_a - set_b  # A에만 있는 값
only_in_b = set_b - set_a  # B에만 있는 값

# 결과 출력
print("A와 B에 모두 있는 값:")
print(common_values)

print("\nA에만 있는 값:")
print(only_in_a)

print("\nB에만 있는 값:")
print(only_in_b)
# Out:
# A와 B에 모두 있는 값:
# {'청운효자동', '수유2동', '신원동', '이문1동', '길동', '서교동', '거여2동', '정릉4동', '쌍문3동', '중곡3동', '우이동', '중계2·3동', '불광1동', '면목5동', '거여1동', '잠실3동', '암사3동', '시흥2동', '공덕동', '마천2동', '성산2동', '일원본동', '응암1동', '북가좌2동', '면목본동', '중곡1동', '둔촌2동', '창신3동', '신길4동', '대학동', '공릉2동', '갈현2동', '번3동', '신사2동', '신길3동', '용신동', '장안1동', '월계1동', '신월2동', '중화1동', '반포4동', '여의동', '면목7동', '삼성1동', '상계8동', '보문동', '신월4동', '삼전동', '잠원동', '면목4동', '행당2동', '개봉3동', '목5동', '중계본동', '숭인1동', '증산동', '장위1동', '문정2동', '구의2동', '신길5동', '풍납1동', '난곡동', '길음1동', '약수동', '홍제1동', '도곡1동', '진관동', '이문2동', '정릉3동', '신정6동', '방학1동', '쌍문4동', '옥수동', '창신1동', '면목3·8동', '일원1동', '종암동', '서원동', '시흥1동', '암사2동', '수서동', '잠실6동', '이촌1동', '목1동', '자양4동', '송정동', '등촌3동', '응봉동', '신정2동', '공항동', '신촌동', '위례동', '다산동', '보라매동', '신정7동', '강일동', '연남동', '반포3동', '자양3동', '갈현1동', '반포본동', '성수2가3동', '상계10동', '합정동', '답십리1동', '남현동', '필동', '금호2·3가동', '신림동', '마천1동', '신월5동', '양평1동', '창5동', '대흥동', '사근동', '구로3동', '이태원1동', '교남동', '노량진2동', '용답동', '삼성동', '대치4동', '혜화동', '상계5동', '용문동', '사직동', '이태원2동', '서초4동', '신내1동', '목2동', '방배본동', '효창동', '도곡2동', '명일2동', '오류2동', '화곡1동', '당산1동', '염창동', '성수1가1동', '월계2동', '천연동', '반포2동', '망원2동', '신월7동', '상도2동', '종로5·6가동', '청량리동', '수유1동', '창3동', '상도4동', '홍제2동', '천호3동', '시흥3동', '방화3동', '화양동', '중곡4동', '청담동', '신당5동', '금호4가동', '독산3동', '상계1동', '고덕1동', '낙성대동', '독산2동', '삼양동', '방배4동', '홍은1동', '가양3동', '제기동', '영등포동', '오류1동', '대림2동', '고척1동', '종로1·2·3·4가동', '방배2동', '역삼2동', '구로1동', '인수동', '등촌1동', '수궁동', '중계1동', '은천동', '상일동', '대림3동', '묵2동', '신정1동', '남가좌2동', '우장산동', '무악동', '묵1동', '서초3동', '남가좌1동', '상봉1동', '평창동', '대조동', '망우본동', '신길6동', '성내2동', '북가좌1동', '신정4동', '개포4동', '황학동', '신대방2동', '중앙동', '남영동', '잠실7동', '잠실2동', '방화2동', '인헌동', '번2동', '응암3동', '면목2동', '상봉2동', '창2동', '돈암2동', '성내3동', '정릉2동', '이촌2동', '도림동', '원효로1동', '자양2동', '석촌동', '성북동', '장안2동', '세곡동', '중곡2동', '양재1동', '신길7동', '고덕2동', '개포2동', '장위3동', '중계4동', '발산1동', '오금동', '신당동', '신사1동', '하계1동', '미아동', '신사동', '답십리2동', '천호1동', '하계2동', '도화동', '화곡3동', '서강동', '행운동', '목4동', '상도3동', '도봉1동', '암사1동', '조원동', '영등포본동', '시흥4동', '신정3동', '역삼1동', '광장동', '회기동', '양재2동', '안암동', '금호1가동', '사당5동', '난향동', '일원2동', '가락2동', '중림동', '월곡2동', '석관동', '등촌2동', '방배1동', '대치1동', '회현동', '자양1동', '상계6·7동', '청룡동', '사당4동', '사당2동', '행당1동', '반포1동', '왕십리2동', '노량진1동', '녹번동', '아현동', '서초2동', '신수동', '송파1동', '화곡2동', '가리봉동', '개포1동', '성내1동', '홍제3동', '삼청동', '목3동', '삼각산동', '구의1동', '상계9동', '쌍문2동', '서빙고동', '장위2동', '한남동', '잠실본동', '이화동', '불광2동', '양평2동', '구로4동', '성산1동', '신월1동', '성현동', '후암동', '사당1동', '신길1동', '천호2동', '전농2동', '광희동', '신내2동', '방화1동', '대림1동', '장충동', '원효로2동', '상계3·4동', '월곡1동', '논현2동', '홍은2동', '청림동', '방이2동', '고척2동', '수유3동', '화곡6동', '방이1동', '공릉1동', '방학3동', '대치2동', '송파2동', '흑석동', '중화2동', '을지로동', '휘경2동', '풍납2동', '신대방1동', '독산1동', '가양2동', '장지동', '전농1동', '오륜동', '번1동', '보광동', '역촌동', '사당3동', '상도1동', '문래동', '휘경1동', '구의3동', '용강동', '성수2가1동', '월계3동', '방배3동', '성수1가2동', '신월6동', '동화동', '관악구 신사동', '길음2동', '서초1동', '충현동', '정릉1동', '논현1동', '명일1동', '연희동', '미성동', '왕십리도선동', '돈암1동', '창1동', '마장동', '군자동', '수색동', '응암2동', '개봉2동', '화곡본동', '서림동', '송중동', '창신2동', '가산동', '시흥5동', '신도림동', '화곡8동', '청파동', '북아현동', '독산4동', '숭인2동', '가락본동', '삼성2동', '부암동', '용산2가동', '동선동', '상계2동', '가회동', '대방동', '당산2동', '둔촌1동', '신월3동', '문정1동', '상암동', '압구정동', '망원1동', '능동', '삼선동', '가락1동', '구산동', '도봉2동', '잠실4동', '내곡동', '망우3동', '한강로동', '가양1동', '송천동', '쌍문1동', '소공동', '구로2동', '명동', '창4동', '청구동', '방학2동', '개봉1동', '구로5동', '화곡4동', '염리동'}
#
# A에만 있는 값:
# {'항동'}
#
# B에만 있는 값:
# set()

# %%
data_01.loc[data_01['행정동_코드_명'] == '항동', '행정동_코드_명'] = '오류2동'

# %%
set_a = set(data_01['행정동_코드_명'])
set_b = set(data_02['동별'])
common_values = set_a & set_b  # A와 B에 모두 있는 값
only_in_a = set_a - set_b  # A에만 있는 값
only_in_b = set_b - set_a  # B에만 있는 값

# 결과 출력
print("A와 B에 모두 있는 값:")
print(common_values)

print("\nA에만 있는 값:")
print(only_in_a)

print("\nB에만 있는 값:")
print(only_in_b)
# Out:
# A와 B에 모두 있는 값:
# {'청운효자동', '수유2동', '신원동', '이문1동', '길동', '서교동', '거여2동', '정릉4동', '쌍문3동', '중곡3동', '우이동', '중계2·3동', '불광1동', '면목5동', '거여1동', '잠실3동', '암사3동', '시흥2동', '공덕동', '마천2동', '성산2동', '일원본동', '응암1동', '북가좌2동', '면목본동', '중곡1동', '둔촌2동', '창신3동', '신길4동', '대학동', '공릉2동', '갈현2동', '번3동', '신사2동', '신길3동', '용신동', '장안1동', '월계1동', '신월2동', '중화1동', '반포4동', '여의동', '면목7동', '삼성1동', '상계8동', '보문동', '신월4동', '삼전동', '잠원동', '면목4동', '행당2동', '개봉3동', '목5동', '중계본동', '숭인1동', '증산동', '장위1동', '문정2동', '구의2동', '신길5동', '풍납1동', '난곡동', '길음1동', '약수동', '홍제1동', '도곡1동', '진관동', '이문2동', '정릉3동', '신정6동', '방학1동', '쌍문4동', '옥수동', '창신1동', '면목3·8동', '일원1동', '종암동', '서원동', '시흥1동', '암사2동', '수서동', '잠실6동', '이촌1동', '목1동', '자양4동', '송정동', '등촌3동', '응봉동', '신정2동', '공항동', '신촌동', '위례동', '다산동', '보라매동', '신정7동', '강일동', '연남동', '반포3동', '자양3동', '갈현1동', '반포본동', '성수2가3동', '상계10동', '합정동', '답십리1동', '남현동', '필동', '금호2·3가동', '신림동', '마천1동', '신월5동', '양평1동', '창5동', '대흥동', '사근동', '구로3동', '이태원1동', '교남동', '노량진2동', '용답동', '삼성동', '대치4동', '혜화동', '상계5동', '용문동', '사직동', '이태원2동', '서초4동', '신내1동', '목2동', '방배본동', '효창동', '도곡2동', '명일2동', '오류2동', '화곡1동', '당산1동', '염창동', '성수1가1동', '월계2동', '천연동', '반포2동', '망원2동', '신월7동', '상도2동', '종로5·6가동', '청량리동', '수유1동', '창3동', '상도4동', '홍제2동', '천호3동', '시흥3동', '방화3동', '화양동', '중곡4동', '청담동', '신당5동', '금호4가동', '독산3동', '상계1동', '고덕1동', '낙성대동', '독산2동', '삼양동', '방배4동', '홍은1동', '가양3동', '제기동', '영등포동', '오류1동', '대림2동', '고척1동', '종로1·2·3·4가동', '방배2동', '역삼2동', '구로1동', '인수동', '등촌1동', '수궁동', '중계1동', '은천동', '상일동', '대림3동', '묵2동', '신정1동', '남가좌2동', '우장산동', '무악동', '묵1동', '서초3동', '남가좌1동', '상봉1동', '평창동', '대조동', '망우본동', '신길6동', '성내2동', '북가좌1동', '신정4동', '개포4동', '황학동', '신대방2동', '중앙동', '남영동', '잠실7동', '잠실2동', '방화2동', '인헌동', '번2동', '응암3동', '면목2동', '상봉2동', '창2동', '돈암2동', '성내3동', '정릉2동', '이촌2동', '도림동', '원효로1동', '자양2동', '석촌동', '성북동', '장안2동', '세곡동', '중곡2동', '양재1동', '신길7동', '고덕2동', '개포2동', '장위3동', '중계4동', '발산1동', '오금동', '신당동', '신사1동', '하계1동', '미아동', '신사동', '답십리2동', '천호1동', '하계2동', '도화동', '화곡3동', '서강동', '행운동', '목4동', '상도3동', '도봉1동', '암사1동', '조원동', '영등포본동', '시흥4동', '신정3동', '역삼1동', '광장동', '회기동', '양재2동', '안암동', '금호1가동', '사당5동', '난향동', '일원2동', '가락2동', '중림동', '월곡2동', '석관동', '등촌2동', '방배1동', '대치1동', '회현동', '자양1동', '상계6·7동', '청룡동', '사당4동', '사당2동', '행당1동', '반포1동', '왕십리2동', '노량진1동', '녹번동', '아현동', '서초2동', '신수동', '송파1동', '화곡2동', '가리봉동', '개포1동', '성내1동', '홍제3동', '삼청동', '목3동', '삼각산동', '구의1동', '상계9동', '쌍문2동', '서빙고동', '장위2동', '한남동', '잠실본동', '이화동', '불광2동', '양평2동', '구로4동', '성산1동', '신월1동', '성현동', '후암동', '사당1동', '신길1동', '천호2동', '전농2동', '광희동', '신내2동', '방화1동', '대림1동', '장충동', '원효로2동', '상계3·4동', '월곡1동', '논현2동', '홍은2동', '청림동', '방이2동', '고척2동', '수유3동', '화곡6동', '방이1동', '공릉1동', '방학3동', '대치2동', '송파2동', '흑석동', '중화2동', '을지로동', '휘경2동', '풍납2동', '신대방1동', '독산1동', '가양2동', '장지동', '전농1동', '오륜동', '번1동', '보광동', '역촌동', '사당3동', '상도1동', '문래동', '휘경1동', '구의3동', '용강동', '성수2가1동', '월계3동', '방배3동', '성수1가2동', '신월6동', '동화동', '관악구 신사동', '길음2동', '서초1동', '충현동', '정릉1동', '논현1동', '명일1동', '연희동', '미성동', '왕십리도선동', '돈암1동', '창1동', '마장동', '군자동', '수색동', '응암2동', '개봉2동', '화곡본동', '서림동', '송중동', '창신2동', '가산동', '시흥5동', '신도림동', '화곡8동', '청파동', '북아현동', '독산4동', '숭인2동', '가락본동', '삼성2동', '부암동', '용산2가동', '동선동', '상계2동', '가회동', '대방동', '당산2동', '둔촌1동', '신월3동', '문정1동', '상암동', '압구정동', '망원1동', '능동', '삼선동', '가락1동', '구산동', '도봉2동', '잠실4동', '내곡동', '망우3동', '한강로동', '가양1동', '송천동', '쌍문1동', '소공동', '구로2동', '명동', '창4동', '청구동', '방학2동', '개봉1동', '구로5동', '화곡4동', '염리동'}
#
# A에만 있는 값:
# set()
#
# B에만 있는 값:
# set()

# %%
data_01.columns
# Out:
# Index(['기준_년분기_코드', '행정동_코드', '행정동_코드_명', '서비스_업종_코드', '서비스_업종_코드_명', '점포_수',
#        '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')

# %% [markdown]
# 서비스 명 통일작업

# %%
data_01['서비스_업종_코드_명'].unique()
# Out:
# array(['한식음식점', '중식음식점', '일식음식점', '양식음식점', '제과점', '패스트푸드점', '치킨전문점',
#        '분식전문점', '호프-간이주점', '커피-음료', '일반교습학원', '외국어학원', '예술학원', '스포츠 강습',
#        '일반의원', '치과의원', '한의원', '동물병원', '변호사사무소', '기타법무서비스', '세무사사무소',
#        '당구장', '골프연습장', '전자게임장', '자동차수리', '자동차미용', '미용실', '네일숍', '피부관리실',
#        '세탁소', '가전제품수리', '부동산중개업', '여관', '게스트하우스', '고시원', '노래방', '녹음실',
#        '사진관', '통번역서비스', '건축물청소', '여행사', '비디오/서적임대', '의류임대', '가정용품임대',
#        '슈퍼마켓', '편의점', '컴퓨터및주변장치판매', '핸드폰', '주류도매', '미곡판매', '육류판매',
#        '수산물판매', '청과상', '반찬가게', '일반의류', '유아의류', '신발', '가방', '안경', '시계및귀금속',
#        '의약품', '의료기기', '서적', '문구', '화장품', '미용재료', '운동/경기용품', '완구', '섬유제품',
#        '화초', '애완동물', '가구', '가전제품', '철물점', '인테리어', '조명용품', '자동차부품',
#        '모터사이클및부품', '재생용품 판매점', '예술품', '전자상거래업', '컴퓨터학원', '변리사사무소',
#        '법무사사무소', '회계사사무소', '볼링장', 'PC방', '기타오락장', '복권방', '통신기기수리',
#        '스포츠클럽', '독서실', '한복점', '자전거 및 기타운송장비', '악기', '주유소', 'DVD방',
#        '모터사이클수리', '중고차판매', '중고가구'], dtype=object)
