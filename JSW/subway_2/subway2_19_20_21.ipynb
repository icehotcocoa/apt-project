# %%
import numpy as np 
import pandas as pd

# %%
sw_19 = pd.read_csv('all_human19.csv')
sw_20 = pd.read_csv('all_human20.csv')
sw_21 = pd.read_csv('all_human21.csv')

# %%
sw_19
sw_20
sw_21
# Out:
#           사용월  호선명_x      지하철역  유임승차인원  무임승차인원  유임하차인원  무임하차인원      작업일자  \
# 0      202112  우이신설선  4.19민주묘지   47280   29715   45573   27003  20220103
# 1      202111  우이신설선  4.19민주묘지   51474   31567   48888   28506  20211203
# 2      202110  우이신설선  4.19민주묘지   47136   33743   45146   29650  20211103
# 3      202109  우이신설선  4.19민주묘지   42324   31747   40940   27938  20211003
# 4      202108  우이신설선  4.19민주묘지   39970   30537   39142   26783  20210903
# ...       ...    ...       ...     ...     ...     ...     ...       ...
# 10066       0      0         0       0       0       0       0         0
# 10067       0      0         0       0       0       0       0         0
# 10068       0      0         0       0       0       0       0         0
# 10069       0      0         0       0       0       0       0         0
# 10070       0      0         0       0       0       0       0         0
#
#        호선명_y    구     동       구_동  총승하차인원   월   분기
# ...

# %%
# sw_19에서 '지하철역' 값이 0인 행 제외
sw_19_st = sw_19[sw_19['지하철역'] != 0]
print("sw_19_st - 지하철역이 0인 데이터 제외:")
print(sw_19_st[['지하철역']].head())
sw_19_st.to_csv('sw_19_st.csv', )

# sw_20에서 '지하철역' 값이 0인 행 제외
sw_20_st = sw_20[sw_20['지하철역'] != 0]
print("\nsw_20_st - 지하철역이 0인 데이터 제외:")
print(sw_20_st[['지하철역']].head())
sw_20_st.to_csv('sw_20_st.csv')

# sw_21에서 '지하철역' 값이 0인 행 제외
sw_21_st = sw_21[sw_21['지하철역'] != 0]
print("\nsw_21_st - 지하철역이 0인 데이터 제외:")
print(sw_21_st[['지하철역']].head())
sw_21_st.to_csv('sw_21_st.csv')
# Out:
# sw_19_st - 지하철역이 0인 데이터 제외:
#        지하철역
# 0  4.19민주묘지
# 1  4.19민주묘지
# 2  4.19민주묘지
# 3  4.19민주묘지
# 4  4.19민주묘지
#
# sw_20_st - 지하철역이 0인 데이터 제외:
#        지하철역
# 0  4.19민주묘지
# 1  4.19민주묘지
# 2  4.19민주묘지
# 3  4.19민주묘지
# 4  4.19민주묘지
#
# sw_21_st - 지하철역이 0인 데이터 제외:
#        지하철역
# 0  4.19민주묘지
# 1  4.19민주묘지
# 2  4.19민주묘지
# 3  4.19민주묘지
# 4  4.19민주묘지
